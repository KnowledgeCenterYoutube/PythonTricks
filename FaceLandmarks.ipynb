# %%
import cv2
import stasm
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# !pip install PyStasm
# Out:
# Collecting PyStasm
#   Downloading https://files.pythonhosted.org/packages/a2/e1/f08c2342d18ef475837522463ed1f48acb5ff6f55dad26cf4d74dea3b878/PyStasm-0.3.1.tar.gz (687kB)
#      |████████████████████████████████| 696kB 5.6MB/s
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from PyStasm) (1.18.5)
# Building wheels for collected packages: PyStasm
#   Building wheel for PyStasm (setup.py) ... done
#   Created wheel for PyStasm: filename=PyStasm-0.3.1-cp36-cp36m-linux_x86_64.whl size=4276880 sha256=4b93bcfcbd02eff79ccb392d486a845dc0183e73864e7545a8f6db2b28413f15
#   Stored in directory: /root/.cache/pip/wheels/88/08/38/caaa7c04eb02ab9bd0b1e80e55e9233e22eb740cd5d1ccf07f
# Successfully built PyStasm
# Installing collected packages: PyStasm
# Successfully installed PyStasm-0.3.1

# %%
img = cv2.imread('Face1.jpg', cv2.IMREAD_GRAYSCALE)
landmarks = stasm.search_single(img)
print(f'landmarks count = {len(landmarks)}')
# Out:
# landmarks count = 77

# %%
fig = plt.figure(figsize=(16, 10))
ax1 = fig.add_subplot(1, 2, 1)
ax1.imshow(img, cmap='gray')

for pt in landmarks:
  cv2.circle(img, (pt[0], pt[1]), 5, (0, 0, 255), -1)

ax2 = fig.add_subplot(1, 2, 2)
ax2.imshow(img, cmap='gray')
